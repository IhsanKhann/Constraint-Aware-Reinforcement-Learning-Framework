# %%
# !pip install numpy scipy matplotlib pandas tqdm gymnasium
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (1.16.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.3.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.3)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !git clone https://github.com/IhsanKhann/Constraint-Aware-Reinforcement-Learning-Framework.git
# Out:
# Cloning into 'Constraint-Aware-Reinforcement-Learning-Framework'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 28 (delta 0), reused 28 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 411.08 KiB | 2.94 MiB/s, done.

# %%
import os
import sys

# 1. Map the directory path
REPO_PATH = '/kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework'

# 2. Append it to the system path so you can use 'import' commands
if REPO_PATH not in sys.path:
    sys.path.append(REPO_PATH)

# 3. Change your active directory to the repo folder
os.chdir(REPO_PATH)
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework

# %%
# !ls -l
# Out:
# total 152
# -rw-r--r-- 1 root root 14874 May 13 15:58 controllers.py
# -rw-r--r-- 1 root root 16140 May 13 15:58 evaluate.py
# -rw-r--r-- 1 root root 14117 May 13 15:58 metrics.py
# drwxr-xr-x 2 root root  4096 May 13 15:58 papers
# -rw-r--r-- 1 root root 22540 May 13 15:58 plotting.py
# drwxr-xr-x 2 root root  4096 May 13 15:58 __pycache__
# -rw-r--r-- 1 root root  9293 May 13 15:58 README.md
# -rw-r--r-- 1 root root    78 May 13 15:58 requirements.txt
# -rw-r--r-- 1 root root 22975 May 13 15:58 run_experiment.py
# -rw-r--r-- 1 root root 10545 May 13 15:58 spacecraft_sim.py
# -rw-r--r-- 1 root root  7557 May 13 15:58 tilecoding.py
# -rw-r--r-- 1 root root 10417 May 13 15:58 train.py

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: scipy>=1.11 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (1.16.3)
# Requirement already satisfied: matplotlib>=3.7 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (3.10.0)
# Requirement already satisfied: pandas>=2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (2.3.3)
# Requirement already satisfied: tqdm>=4.65 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (4.67.3)
# Requirement already satisfied: gymnasium>=0.29 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 6)) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.7->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 4)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.0->-r requirements.txt (line 4)) (2025.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.29->-r requirements.txt (line 6)) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.29->-r requirements.txt (line 6)) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium>=0.29->-r requirements.txt (line 6)) (0.0.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.7->-r requirements.txt (line 3)) (1.17.0)

# %%
# !python run_experiment.py --agent both --episodes 10000 --log-every 200
# Out:
# ======================================================================
#   SPACECRAFT RL EXPERIMENT - FULL PIPELINE
# ======================================================================
#   Training episodes  : 10000
#   Evaluation trials  : 50
#   Random seed        : 42
#   Skip training      : False
#   Results directory  : results
# [setup] Results directory: /kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework/results
#
# ----------------------------------------------------------------------
#   PHASE 1: Train Standard RL Agent
# ----------------------------------------------------------------------
#
# Training Standard RL for 10000 episodes ...
# Training: 100%|█| 10000/10000 [2:56:21<00:00,  1.06s/it, eps=0.050, eval_err=2.5
#
# Training complete in 176.36 min
#   Final epsilon: 0.0500
#   Final eval error: 2.5503
#   Finished in 176.4 min  |  final eps = 0.0500  |  final eval error = 2.5503
#   JSON saved -> results/logs/standard_rl_training.json
#
# ----------------------------------------------------------------------
#   PHASE 2: Train Constraint-Aware RL Agent
# ----------------------------------------------------------------------
#
# Training CA-RL for 10000 episodes ...
# Training: 100%|█| 10000/10000 [2:58:54<00:00,  1.07s/it, eps=0.050, eval_err=2.4
#
# Training complete in 178.92 min
#   Final epsilon: 0.0500
#   Final eval error: 2.4497
#   Finished in 178.9 min  |  final eps = 0.0500  |  final eval error = 2.4497
#   JSON saved -> results/logs/ca_rl_training.json
#
# ----------------------------------------------------------------------
#   PHASE 3: Save Q-tables
# ----------------------------------------------------------------------
#   Q-table saved -> results/qtables/standard_rl_qtable.npy
#   Q-table saved -> results/qtables/ca_rl_qtable.npy
#   Plot saved → results/plots/training_rewards.png
#
# ----------------------------------------------------------------------
#   PHASE 4: Evaluate All Controllers (50 episodes each)
# ----------------------------------------------------------------------
#   Evaluating PID (50 episodes) ...
#     PID  -> SSE=0.0041  ATV=10.66
#   Evaluating Standard RL (50 episodes) ...
#     Std RL -> SSE=2.7352  ATV=650.08
#   Evaluating CA-RL (50 episodes) ...
#     CA-RL -> SSE=2.7917  ATV=662.26
#
# ----------------------------------------------------------------------
#   PHASE 5: Assemble Per-Episode Metric Arrays for Plotting
# ----------------------------------------------------------------------
#
# ----------------------------------------------------------------------
#   PHASE 6: Generate Publication-Quality Plots
# ----------------------------------------------------------------------
#
# [plotting] Generating all figures → results/plots
#   Plot saved → results/plots/training_rewards.png
#   Plot saved → results/plots/tracking_error.png
#   Plot saved → results/plots/atv_comparison.png
#   Plot saved → results/plots/control_energy.png
#   Plot saved → results/plots/settling_time.png
#   Plot saved → results/plots/controller_summary.png
#   Plot saved → results/plots/monte_carlo_robustness.png
#   Plot saved → results/plots/actuator_profile.png
# [plotting] All figures saved to results/plots
#
#
# ----------------------------------------------------------------------
#   PHASE 7: Export CSV Results
# ----------------------------------------------------------------------
#   Metrics summary CSV → results/csv/metrics_summary.csv
#   Metrics raw CSV    → results/csv/metrics_raw.csv
#   JSON saved -> results/logs/evaluation_summary.json
#   PID episodes CSV -> results/csv/pid_episodes.csv
#   Standard RL episodes CSV -> results/csv/standard_rl_episodes.csv
#   CA-RL episodes CSV -> results/csv/ca_rl_episodes.csv
#
# ----------------------------------------------------------------------
#   PHASE 8: Final Comparison Summary
# ----------------------------------------------------------------------
#
# ======================================================================
#   FINAL EXPERIMENT SUMMARY
# ======================================================================
#                      Metric                PID          Standard RL                CA-RL
#    Steady-State Error (rad)    0.0041 ± 0.0015      2.7352 ± 0.5096      2.7917 ± 0.5179
#           Settling Time (s) 137.2800 ± 27.4387   279.9200 ± 20.2848   284.9800 ± 26.0849
#    Actuator Total Variation   10.6583 ± 2.0451   650.0800 ± 54.6783   662.2600 ± 65.6581
#       Control Energy (N²·s)  68.3200 ± 39.9166 1484.6400 ± 106.3836 1514.5600 ± 147.0147
# Disturbance Rejection (rad)    0.0865 ± 0.0315      2.7324 ± 0.2266      2.7691 ± 0.2288
#
#   Best controller per metric (* = best):
#   Metric                              Best Controller           Value
#   ----------------------------------- -------------------- ----------
#   Steady-State Error                  PID                      0.0041
#   Settling Time                       PID                    137.2800
#   Actuator Total Variation            PID                     10.6583
#   Control Energy                      PID                     68.3200
#   Disturbance Rejection               PID                      0.0865
#
#
# ======================================================================
#   EXPERIMENT COMPLETE  (357.0 min total)
# ======================================================================
#   Plots   -> results/plots
#   CSVs    -> results/csv
#   Q-tables-> results/qtables
#   Logs    -> results/logs

# %%
# !ls -la /kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework/
# Out:
# total 168
# drwxr-xr-x 6 root root  4096 May 13 15:58 .
# drwxr-xr-x 3 root root  4096 May 13 15:58 ..
# -rw-r--r-- 1 root root 14874 May 13 15:58 controllers.py
# -rw-r--r-- 1 root root 16140 May 13 15:58 evaluate.py
# drwxr-xr-x 8 root root  4096 May 13 15:58 .git
# -rw-r--r-- 1 root root 14117 May 13 15:58 metrics.py
# drwxr-xr-x 2 root root  4096 May 13 15:58 papers
# -rw-r--r-- 1 root root 22540 May 13 15:58 plotting.py
# drwxr-xr-x 2 root root  4096 May 13 15:58 __pycache__
# -rw-r--r-- 1 root root  9293 May 13 15:58 README.md
# -rw-r--r-- 1 root root    78 May 13 15:58 requirements.txt
# drwxr-xr-x 6 root root  4096 May 13 15:58 results
# -rw-r--r-- 1 root root 22975 May 13 15:58 run_experiment.py
# -rw-r--r-- 1 root root 10545 May 13 15:58 spacecraft_sim.py
# -rw-r--r-- 1 root root  7557 May 13 15:58 tilecoding.py
# -rw-r--r-- 1 root root 10417 May 13 15:58 train.py
