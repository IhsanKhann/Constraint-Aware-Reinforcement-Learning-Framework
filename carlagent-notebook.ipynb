# %%
# !pip install numpy scipy matplotlib pandas tqdm gymnasium

# %%
# !git clone https://github.com/IhsanKhann/Constraint-Aware-Reinforcement-Learning-Framework.git
# Out:
# Cloning into 'Constraint-Aware-Reinforcement-Learning-Framework'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 28 (delta 0), reused 28 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (28/28), 411.08 KiB | 4.78 MiB/s, done.

# %%
import os
import sys

# 1. Map the directory path
REPO_PATH = '/kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework'

# 2. Append it to the system path so you can use 'import' commands
if REPO_PATH not in sys.path:
    sys.path.append(REPO_PATH)

# 3. Change your active directory to the repo folder
os.chdir(REPO_PATH)
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: /kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework

# %%
# !ls -l
# Out:
# total 152
# -rw-r--r-- 1 root root 14874 May 13 15:35 controllers.py
# -rw-r--r-- 1 root root 16140 May 13 15:35 evaluate.py
# -rw-r--r-- 1 root root 14117 May 13 15:35 metrics.py
# drwxr-xr-x 2 root root  4096 May 13 15:35 papers
# -rw-r--r-- 1 root root 22540 May 13 15:35 plotting.py
# drwxr-xr-x 2 root root  4096 May 13 15:35 __pycache__
# -rw-r--r-- 1 root root  9293 May 13 15:35 README.md
# -rw-r--r-- 1 root root    78 May 13 15:35 requirements.txt
# -rw-r--r-- 1 root root 22975 May 13 15:35 run_experiment.py
# -rw-r--r-- 1 root root 10545 May 13 15:35 spacecraft_sim.py
# -rw-r--r-- 1 root root  7557 May 13 15:35 tilecoding.py
# -rw-r--r-- 1 root root 10417 May 13 15:35 train.py

# %%
# !pip install -r requirements.txt

# %%
# !python run_experiment.py --agent both --episodes 10000 --log-every 200

# %%
# Out:
# total 152
# -rw-r--r-- 1 root root 14874 May 13 15:35 controllers.py
# -rw-r--r-- 1 root root 16140 May 13 15:35 evaluate.py
# -rw-r--r-- 1 root root 14117 May 13 15:35 metrics.py
# drwxr-xr-x 2 root root  4096 May 13 15:35 papers
# -rw-r--r-- 1 root root 22540 May 13 15:35 plotting.py
# drwxr-xr-x 2 root root  4096 May 13 15:35 __pycache__
# -rw-r--r-- 1 root root  9293 May 13 15:35 README.md
# -rw-r--r-- 1 root root    78 May 13 15:35 requirements.txt
# -rw-r--r-- 1 root root 22975 May 13 15:35 run_experiment.py
# -rw-r--r-- 1 root root 10545 May 13 15:35 spacecraft_sim.py
# -rw-r--r-- 1 root root  7557 May 13 15:35 tilecoding.py
# -rw-r--r-- 1 root root 10417 May 13 15:35 train.py

# %%
# !ls -la /kaggle/working/Constraint-Aware-Reinforcement-Learning-Framework/
# Out:
# total 164
# drwxr-xr-x 5 root root  4096 May 13 15:35 .
# drwxr-xr-x 4 root root  4096 May 13 15:35 ..
# -rw-r--r-- 1 root root 14874 May 13 15:35 controllers.py
# -rw-r--r-- 1 root root 16140 May 13 15:35 evaluate.py
# drwxr-xr-x 8 root root  4096 May 13 15:35 .git
# -rw-r--r-- 1 root root 14117 May 13 15:35 metrics.py
# drwxr-xr-x 2 root root  4096 May 13 15:35 papers
# -rw-r--r-- 1 root root 22540 May 13 15:35 plotting.py
# drwxr-xr-x 2 root root  4096 May 13 15:35 __pycache__
# -rw-r--r-- 1 root root  9293 May 13 15:35 README.md
# -rw-r--r-- 1 root root    78 May 13 15:35 requirements.txt
# -rw-r--r-- 1 root root 22975 May 13 15:35 run_experiment.py
# -rw-r--r-- 1 root root 10545 May 13 15:35 spacecraft_sim.py
# -rw-r--r-- 1 root root  7557 May 13 15:35 tilecoding.py
# -rw-r--r-- 1 root root 10417 May 13 15:35 train.py
